# %% [markdown]
# ### Download and import necessary packages

# %%
BUCKET_NAME = "YOUR_BUCKET"
# Change the bucket name with your own

# %%
# %%capture
# !pip install -r /home/neuro/codes/questionnaire_brain/requirements_multivariate_prediction.txt;

# %%
import os
import sys
import glob
import pickle
import time
import random
import boto3
import numpy as np
import pandas as pd
import nibabel as nib
from nltools.data import Brain_Data
from multiprocessing import Pool, cpu_count
# Prevent warnings to be displayed
import warnings
warnings.filterwarnings('ignore')
# Prevent global variables
from noglobal import NoGlobal
noglobal = NoGlobal(globals()).noglobal

# %%
print(sys.version)
# !pip freeze > requirements_my_concat_social_isolation.txt
# Out:
# 3.9.15 | packaged by conda-forge | (main, Nov 22 2022, 08:45:29)
# [GCC 10.4.0]

# %%
# Here, we decide your working directory
initial_directory = "/home/neuro/mount/"
data_directory = os.path.join(initial_directory, "run_concat_social_isolation_data")
# Create data_directory if it doesn't exist
if not os.path.exists(data_directory):
    os.makedirs(data_directory)

# %% [markdown]
# ### Check and set versions

# %%
def fix_seed(seed):
    # random
    random.seed(seed)
    # Numpy
    np.random.seed(seed)

# Set seed to 42 for both Numpy and random
SEED = 42
fix_seed(SEED)

# %% [markdown]
# ### Set up AWS S3

# %%
# Create Directory if it doesn't exist already.
if not os.path.exists('/root/.aws'):
    os.makedirs('/root/.aws')
    # Put credential on host into guest
    ! cp /home/neuro/credential/your_s3_credentials ~/.aws/credentials

# %%
# Download or Upload to s3 bucket.
@noglobal
def cp_s3(BUCKET_NAME, FROM_PATH, TO_PATH, FILE_NAME, download_or_upload):
    s3_resource = boto3.resource('s3')
    bucket = s3_resource.Bucket(BUCKET_NAME)

    from_path = os.path.join(FROM_PATH, FILE_NAME)
    to_path = os.path.join(TO_PATH, FILE_NAME)
    
    if download_or_upload == "download":
        print("Downloading from S3 bucket!")
        bucket.download_file(from_path, to_path)
    elif download_or_upload == "upload":
        print("Uplaoding to S3 bucket!")
        bucket.upload_file(from_path, to_path)
    else:
        raise ValueError('Please specify download or upload.')
    return

# %% [markdown]
# ### Creates a list of session id - with its subfiles

# %%
# Fetches all the file keys in a given bucket using pagination.
def paginate_objects(bucket_name):
    s3 = boto3.client('s3')
    paginator = s3.get_paginator('list_objects_v2')
    
    file_list = []
    for page in paginator.paginate(Bucket=bucket_name):
        for obj in page['Contents']:
            file_list.append(obj['Key'])
    return file_list

file_list = paginate_objects(BUCKET_NAME)

# Remove the prefix and suffix and returns it back.
def rem_str_func(val):
    return val.removeprefix(prefix_str).removesuffix(suffix_str)

# %%
# Task: CIC

# Filters files that start with a specific prefix.
prefix_str = 'outputdir/glmsingle_output/'
l_start = [s for s in file_list if s.startswith(prefix_str)]
display(len(l_start))
# Filters files that end with a specific suffix among the above list.
suffix_str = '/beta_img.nii.gz'
l_end = [s for s in l_start if s.endswith(suffix_str)]
display(len(l_end))

# Creates a list of session ids for tasks CIC
session_ids_CIC = list(map(rem_str_func, l_end))
# Out:
# 192
# 96

# %%
# Task: midloc

# Filters files that start with a specific prefix.
prefix_str = 'outputdir/glmsingle_output_midloc/'
l_start = [s for s in file_list if s.startswith(prefix_str)]
display(len(l_start))
# Filters files that end with a specific suffix among the above list.
suffix_str = '/beta_img.nii.gz'
l_end = [s for s in l_start if s.endswith(suffix_str)]
display(len(l_end))

# Creates a list of session ids for tasks midloc
session_ids_midloc = list(map(rem_str_func, l_end))
# Out:
# 64
# 32

# %% [markdown]
# ### Download GLMsingle output

# %%
# Downloads the brain data and corresponding event data from S3, and returns it as a Brain_Data object.
@noglobal
def make_brain_data(session_id, BUCKET_NAME, data_directory, s3_dir):
    # Will be downloaded from...
    FROM_PATH = os.path.join(s3_dir,  session_id)
    # Will be downloaded to...
    TO_PATH = os.path.join(data_directory, session_id)
    # Check if download destination exists, if not, make one.
    if not os.path.exists(TO_PATH):
        os.makedirs(TO_PATH)
    
    # Downloades betamap from s3 bucket.
    print(f"Downloading betamap of {session_id}!")
    FILE_NAME = "beta_img.nii.gz"
    cp_s3(BUCKET_NAME, FROM_PATH, TO_PATH, FILE_NAME, "download")
    # Load it as a nibabel image.
    img = nib.load(os.path.join(TO_PATH, FILE_NAME))
    print("Converting into Brain_Data!")
    # Convert it to a Brain_Data object.
    data = Brain_Data(img)
    
    # Downloads eventdata from s3 bucket.
    print(f"Downloading eventfile of {session_id}!")
    FILE_NAME = "events.csv"
    cp_s3(BUCKET_NAME, FROM_PATH, TO_PATH, FILE_NAME, "download")
    # Convert it into a dataframe
    design_df_concat = pd.read_csv(os.path.join(TO_PATH, FILE_NAME))
    
    return data, design_df_concat

# %% [markdown]
# ### Perform concatenation

# %%
# Do concatenation and save concat data
@noglobal
def concat_func(session_ids_CIC, session_ids_midloc, BUCKET_NAME, data_directory):
    
    #Output: 
    #Brain_data.data = concatenated brain_data of all sessions in {session_ids}
    #Brain_data.Y = the trial_type and session_id
    
    print(f"Starting concatenation for {session_ids_CIC} and {session_ids_midloc}!")
    
    
    FROM_PATH = os.path.join(data_directory,'concat_output')
    TO_PATH = "outputdir/concat_output"
    
    if not os.path.exists(FROM_PATH):
        os.makedirs(FROM_PATH)
    
    braindata = Brain_Data()
    df = pd.DataFrame()
    
    # Concatenating Brain_Data and design_df of all sessions
    for session_id in session_ids_CIC:
        # Obtain brain data and event data for each session
        braindata_current, design_df_concat = make_brain_data(session_id, BUCKET_NAME, data_directory, 'outputdir/glmsingle_output/')
        # Add a column named "session" which includes the particular session_id
        design_df_concat['session'] = session_id
        design_df_concat = design_df_concat[design_df_concat['trial_type'] != "Rati"].reset_index(drop=True)
        # Concatenate the brain_data
        braindata = braindata.append(braindata_current)
        print("braindata shape: " + str(braindata.shape()))
        # Concatenate the design_df
        df = pd.concat([df, design_df_concat])
        print("df shape: " + str(df.shape))
    
    # Concatenating Brain_Data and design_df of all sessions
    for session_id in session_ids_midloc:
        # Obtain brain data and event data for each session
        braindata_current, design_df_concat = make_brain_data(session_id, BUCKET_NAME, data_directory, 'outputdir/glmsingle_output_midloc/')
        # Add a column named "session" which includes the particular session_id
        design_df_concat['session'] = session_id
        # Concatenate the brain_data
        braindata = braindata.append(braindata_current)
        print("braindata shape: " + str(braindata.shape()))
        # Concatenate the design_df
        df = pd.concat([df, design_df_concat])
        print("df shape: " + str(df.shape))


    print("Concatenation finished!")
    
    # Apply trial_type and session_id to braindata.Y
    braindata.Y = pd.DataFrame(df[['session', 'trial_type']])
    print(f"Braindata.data shape: {braindata.shape()}")
    print(f"Braindata.Y: {braindata.Y}")
    
    print("Saving your cocatenation outputs!")
    # Serializes and saves braindata as a pickle file at FROM_PATH
    FILE_NAME = "braindata.pickle"
    with open(os.path.join(FROM_PATH, FILE_NAME), mode="wb") as f:
        pickle.dump(braindata, f)

    # Uploads the pickled braindata to S3 bucket
    cp_s3(BUCKET_NAME, FROM_PATH, TO_PATH, FILE_NAME, "upload")
    
    # Deletes the concatenation outputs as well as GLMsingle files
    # !rm -rf $FROM_PATH
    # !rm -rf $data_directory

    return braindata

# %%
# Checks the disk usage before the operations.
# !df -h -m --total
# Out:
# Filesystem     1M-blocks  Used Available Use% Mounted on
# overlay            99189 38932     60242  40% /
# tmpfs                 64     0        64   0% /dev
# tmpfs              31639     0     31639   0% /sys/fs/cgroup
# shm                   64     0        64   0% /dev/shm
# /dev/root          99189 38932     60242  40% /etc/hosts
# /dev/nvme1n1      451821  7709    444113   2% /home/neuro/mount
# tmpfs              31639     0     31639   0% /proc/acpi
# tmpfs              31639     0     31639   0% /proc/scsi
# tmpfs              31639     0     31639   0% /sys/firmware
# total             776880 85571    691277  12% -

# %%
# Start of time measurement
time_sta = time.time()

# Perform concatenation
braindata = concat_func(session_ids_CIC, session_ids_midloc, BUCKET_NAME, data_directory)

# Time measurement end
time_end = time.time()
tim = time_end- time_sta

print(str(round(tim)) + " seconds")
print(str(round(tim/60)) + " minutes")
# Out:
# Starting concatenation for ['sub-SAXSISO01b', 'sub-SAXSISO01f', 'sub-SAXSISO01s', 'sub-SAXSISO02b', 'sub-SAXSISO02f', 'sub-SAXSISO02s', 'sub-SAXSISO03b', 'sub-SAXSISO03f', 'sub-SAXSISO03s', 'sub-SAXSISO04b', 'sub-SAXSISO04f', 'sub-SAXSISO04s', 'sub-SAXSISO08b', 'sub-SAXSISO08f', 'sub-SAXSISO08s', 'sub-SAXSISO09b', 'sub-SAXSISO09f', 'sub-SAXSISO09s', 'sub-SAXSISO10b', 'sub-SAXSISO10f', 'sub-SAXSISO10s', 'sub-SAXSISO11b', 'sub-SAXSISO11f', 'sub-SAXSISO11s', 'sub-SAXSISO12b', 'sub-SAXSISO12f', 'sub-SAXSISO12s', 'sub-SAXSISO13b', 'sub-SAXSISO13f', 'sub-SAXSISO13s', 'sub-SAXSISO14b', 'sub-SAXSISO14f', 'sub-SAXSISO14s', 'sub-SAXSISO15b', 'sub-SAXSISO15f', 'sub-SAXSISO15s', 'sub-SAXSISO17b', 'sub-SAXSISO17f', 'sub-SAXSISO17s', 'sub-SAXSISO18b', 'sub-SAXSISO18f', 'sub-SAXSISO18s', 'sub-SAXSISO19b', 'sub-SAXSISO19f', 'sub-SAXSISO19s', 'sub-SAXSISO21b', 'sub-SAXSISO21f', 'sub-SAXSISO21s', 'sub-SAXSISO22b', 'sub-SAXSISO22f', 'sub-SAXSISO22s', 'sub-SAXSISO24b', 'sub-SAXSISO24f', 'sub-SAXSISO24s', 'sub-SAXSISO26b', 'sub-SAXSISO26f', 'sub-SAXSISO26s', 'sub-SAXSISO27b', 'sub-SAXSISO27f', 'sub-SAXSISO27s', 'sub-SAXSISO28b', 'sub-SAXSISO28f', 'sub-SAXSISO28s', 'sub-SAXSISO30b', 'sub-SAXSISO30f', 'sub-SAXSISO30s', 'sub-SAXSISO32b', 'sub-SAXSISO32f', 'sub-SAXSISO32s', 'sub-SAXSISO33b', 'sub-SAXSISO33f', 'sub-SAXSISO33s', 'sub-SAXSISO34b', 'sub-SAXSISO34f', 'sub-SAXSISO34s', 'sub-SAXSISO35b', 'sub-SAXSISO35f', 'sub-SAXSISO35s', 'sub-SAXSISO36b', 'sub-SAXSISO36f', 'sub-SAXSISO36s', 'sub-SAXSISO38b', 'sub-SAXSISO38f', 'sub-SAXSISO38s', 'sub-SAXSISO39b', 'sub-SAXSISO39f', 'sub-SAXSISO39s', 'sub-SAXSISO40b', 'sub-SAXSISO40f', 'sub-SAXSISO40s', 'sub-SAXSISO41b', 'sub-SAXSISO41f', 'sub-SAXSISO41s', 'sub-SAXSISO42b', 'sub-SAXSISO42f', 'sub-SAXSISO42s'] and ['sub-SAXSISO01b', 'sub-SAXSISO02b', 'sub-SAXSISO03b', 'sub-SAXSISO04b', 'sub-SAXSISO08b', 'sub-SAXSISO09b', 'sub-SAXSISO10b', 'sub-SAXSISO11b', 'sub-SAXSISO12b', 'sub-SAXSISO13b', 'sub-SAXSISO14b', 'sub-SAXSISO15b', 'sub-SAXSISO17b', 'sub-SAXSISO18b', 'sub-SAXSISO19b', 'sub-SAXSISO21b', 'sub-SAXSISO22b', 'sub-SAXSISO24b', 'sub-SAXSISO26b', 'sub-SAXSISO27b', 'sub-SAXSISO28b', 'sub-SAXSISO30b', 'sub-SAXSISO32b', 'sub-SAXSISO33b', 'sub-SAXSISO34b', 'sub-SAXSISO35b', 'sub-SAXSISO36b', 'sub-SAXSISO38b', 'sub-SAXSISO39b', 'sub-SAXSISO40b', 'sub-SAXSISO41b', 'sub-SAXSISO42b']!
# Downloading betamap of sub-SAXSISO01b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO01b!
# Downloading from S3 bucket!
# braindata shape: (54, 238955)
# df shape: (54, 8)
# Downloading betamap of sub-SAXSISO01f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO01f!
# Downloading from S3 bucket!
# braindata shape: (108, 238955)
# df shape: (108, 8)
# Downloading betamap of sub-SAXSISO01s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO01s!
# Downloading from S3 bucket!
# braindata shape: (162, 238955)
# df shape: (162, 8)
# Downloading betamap of sub-SAXSISO02b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO02b!
# Downloading from S3 bucket!
# braindata shape: (216, 238955)
# df shape: (216, 8)
# Downloading betamap of sub-SAXSISO02f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO02f!
# Downloading from S3 bucket!
# braindata shape: (270, 238955)
# df shape: (270, 8)
# Downloading betamap of sub-SAXSISO02s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO02s!
# Downloading from S3 bucket!
# braindata shape: (324, 238955)
# df shape: (324, 8)
# Downloading betamap of sub-SAXSISO03b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO03b!
# Downloading from S3 bucket!
# braindata shape: (378, 238955)
# df shape: (378, 8)
# Downloading betamap of sub-SAXSISO03f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO03f!
# Downloading from S3 bucket!
# braindata shape: (432, 238955)
# df shape: (432, 8)
# Downloading betamap of sub-SAXSISO03s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO03s!
# Downloading from S3 bucket!
# braindata shape: (486, 238955)
# df shape: (486, 8)
# Downloading betamap of sub-SAXSISO04b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO04b!
# Downloading from S3 bucket!
# braindata shape: (540, 238955)
# df shape: (540, 8)
# Downloading betamap of sub-SAXSISO04f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO04f!
# Downloading from S3 bucket!
# braindata shape: (594, 238955)
# df shape: (594, 8)
# Downloading betamap of sub-SAXSISO04s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO04s!
# Downloading from S3 bucket!
# braindata shape: (648, 238955)
# df shape: (648, 8)
# Downloading betamap of sub-SAXSISO08b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO08b!
# Downloading from S3 bucket!
# braindata shape: (702, 238955)
# df shape: (702, 8)
# Downloading betamap of sub-SAXSISO08f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO08f!
# Downloading from S3 bucket!
# braindata shape: (756, 238955)
# df shape: (756, 8)
# Downloading betamap of sub-SAXSISO08s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO08s!
# Downloading from S3 bucket!
# braindata shape: (810, 238955)
# df shape: (810, 8)
# Downloading betamap of sub-SAXSISO09b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO09b!
# Downloading from S3 bucket!
# braindata shape: (855, 238955)
# df shape: (855, 8)
# Downloading betamap of sub-SAXSISO09f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO09f!
# Downloading from S3 bucket!
# braindata shape: (909, 238955)
# df shape: (909, 8)
# Downloading betamap of sub-SAXSISO09s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO09s!
# Downloading from S3 bucket!
# braindata shape: (963, 238955)
# df shape: (963, 8)
# Downloading betamap of sub-SAXSISO10b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO10b!
# Downloading from S3 bucket!
# braindata shape: (1017, 238955)
# df shape: (1017, 8)
# Downloading betamap of sub-SAXSISO10f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO10f!
# Downloading from S3 bucket!
# braindata shape: (1071, 238955)
# df shape: (1071, 8)
# Downloading betamap of sub-SAXSISO10s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO10s!
# Downloading from S3 bucket!
# braindata shape: (1125, 238955)
# df shape: (1125, 8)
# Downloading betamap of sub-SAXSISO11b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO11b!
# Downloading from S3 bucket!
# braindata shape: (1179, 238955)
# df shape: (1179, 8)
# Downloading betamap of sub-SAXSISO11f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO11f!
# Downloading from S3 bucket!
# braindata shape: (1233, 238955)
# df shape: (1233, 8)
# Downloading betamap of sub-SAXSISO11s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO11s!
# Downloading from S3 bucket!
# braindata shape: (1287, 238955)
# df shape: (1287, 8)
# Downloading betamap of sub-SAXSISO12b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO12b!
# Downloading from S3 bucket!
# braindata shape: (1341, 238955)
# df shape: (1341, 8)
# Downloading betamap of sub-SAXSISO12f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO12f!
# Downloading from S3 bucket!
# braindata shape: (1395, 238955)
# df shape: (1395, 8)
# Downloading betamap of sub-SAXSISO12s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO12s!
# Downloading from S3 bucket!
# braindata shape: (1449, 238955)
# df shape: (1449, 8)
# Downloading betamap of sub-SAXSISO13b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO13b!
# Downloading from S3 bucket!
# braindata shape: (1503, 238955)
# df shape: (1503, 8)
# Downloading betamap of sub-SAXSISO13f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO13f!
# Downloading from S3 bucket!
# braindata shape: (1557, 238955)
# df shape: (1557, 8)
# Downloading betamap of sub-SAXSISO13s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO13s!
# Downloading from S3 bucket!
# braindata shape: (1611, 238955)
# df shape: (1611, 8)
# Downloading betamap of sub-SAXSISO14b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO14b!
# Downloading from S3 bucket!
# braindata shape: (1665, 238955)
# df shape: (1665, 8)
# Downloading betamap of sub-SAXSISO14f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO14f!
# Downloading from S3 bucket!
# braindata shape: (1719, 238955)
# df shape: (1719, 8)
# Downloading betamap of sub-SAXSISO14s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO14s!
# Downloading from S3 bucket!
# braindata shape: (1773, 238955)
# df shape: (1773, 8)
# Downloading betamap of sub-SAXSISO15b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO15b!
# Downloading from S3 bucket!
# braindata shape: (1827, 238955)
# df shape: (1827, 8)
# Downloading betamap of sub-SAXSISO15f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO15f!
# Downloading from S3 bucket!
# braindata shape: (1881, 238955)
# df shape: (1881, 8)
# Downloading betamap of sub-SAXSISO15s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO15s!
# Downloading from S3 bucket!
# braindata shape: (1935, 238955)
# df shape: (1935, 8)
# Downloading betamap of sub-SAXSISO17b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO17b!
# Downloading from S3 bucket!
# braindata shape: (1989, 238955)
# df shape: (1989, 8)
# Downloading betamap of sub-SAXSISO17f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO17f!
# Downloading from S3 bucket!
# braindata shape: (2043, 238955)
# df shape: (2043, 8)
# Downloading betamap of sub-SAXSISO17s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO17s!
# Downloading from S3 bucket!
# braindata shape: (2097, 238955)
# df shape: (2097, 8)
# Downloading betamap of sub-SAXSISO18b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO18b!
# Downloading from S3 bucket!
# braindata shape: (2151, 238955)
# df shape: (2151, 8)
# Downloading betamap of sub-SAXSISO18f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO18f!
# Downloading from S3 bucket!
# braindata shape: (2205, 238955)
# df shape: (2205, 8)
# Downloading betamap of sub-SAXSISO18s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO18s!
# Downloading from S3 bucket!
# braindata shape: (2259, 238955)
# df shape: (2259, 8)
# Downloading betamap of sub-SAXSISO19b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO19b!
# Downloading from S3 bucket!
# braindata shape: (2313, 238955)
# df shape: (2313, 8)
# Downloading betamap of sub-SAXSISO19f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO19f!
# Downloading from S3 bucket!
# braindata shape: (2367, 238955)
# df shape: (2367, 8)
# Downloading betamap of sub-SAXSISO19s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO19s!
# Downloading from S3 bucket!
# braindata shape: (2421, 238955)
# df shape: (2421, 8)
# Downloading betamap of sub-SAXSISO21b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO21b!
# Downloading from S3 bucket!
# braindata shape: (2475, 238955)
# df shape: (2475, 8)
# Downloading betamap of sub-SAXSISO21f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO21f!
# Downloading from S3 bucket!
# braindata shape: (2529, 238955)
# df shape: (2529, 8)
# Downloading betamap of sub-SAXSISO21s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO21s!
# Downloading from S3 bucket!
# braindata shape: (2583, 238955)
# df shape: (2583, 8)
# Downloading betamap of sub-SAXSISO22b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO22b!
# Downloading from S3 bucket!
# braindata shape: (2637, 238955)
# df shape: (2637, 8)
# Downloading betamap of sub-SAXSISO22f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO22f!
# Downloading from S3 bucket!
# braindata shape: (2691, 238955)
# df shape: (2691, 8)
# Downloading betamap of sub-SAXSISO22s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO22s!
# Downloading from S3 bucket!
# braindata shape: (2745, 238955)
# df shape: (2745, 8)
# Downloading betamap of sub-SAXSISO24b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO24b!
# Downloading from S3 bucket!
# braindata shape: (2799, 238955)
# df shape: (2799, 8)
# Downloading betamap of sub-SAXSISO24f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO24f!
# Downloading from S3 bucket!
# braindata shape: (2853, 238955)
# df shape: (2853, 8)
# Downloading betamap of sub-SAXSISO24s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO24s!
# Downloading from S3 bucket!
# braindata shape: (2907, 238955)
# df shape: (2907, 8)
# Downloading betamap of sub-SAXSISO26b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO26b!
# Downloading from S3 bucket!
# braindata shape: (2961, 238955)
# df shape: (2961, 8)
# Downloading betamap of sub-SAXSISO26f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO26f!
# Downloading from S3 bucket!
# braindata shape: (3015, 238955)
# df shape: (3015, 8)
# Downloading betamap of sub-SAXSISO26s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO26s!
# Downloading from S3 bucket!
# braindata shape: (3069, 238955)
# df shape: (3069, 8)
# Downloading betamap of sub-SAXSISO27b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO27b!
# Downloading from S3 bucket!
# braindata shape: (3123, 238955)
# df shape: (3123, 8)
# Downloading betamap of sub-SAXSISO27f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO27f!
# Downloading from S3 bucket!
# braindata shape: (3177, 238955)
# df shape: (3177, 8)
# Downloading betamap of sub-SAXSISO27s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO27s!
# Downloading from S3 bucket!
# braindata shape: (3231, 238955)
# df shape: (3231, 8)
# Downloading betamap of sub-SAXSISO28b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO28b!
# Downloading from S3 bucket!
# braindata shape: (3285, 238955)
# df shape: (3285, 8)
# Downloading betamap of sub-SAXSISO28f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO28f!
# Downloading from S3 bucket!
# braindata shape: (3339, 238955)
# df shape: (3339, 8)
# Downloading betamap of sub-SAXSISO28s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO28s!
# Downloading from S3 bucket!
# braindata shape: (3393, 238955)
# df shape: (3393, 8)
# Downloading betamap of sub-SAXSISO30b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO30b!
# Downloading from S3 bucket!
# braindata shape: (3447, 238955)
# df shape: (3447, 8)
# Downloading betamap of sub-SAXSISO30f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO30f!
# Downloading from S3 bucket!
# braindata shape: (3501, 238955)
# df shape: (3501, 8)
# Downloading betamap of sub-SAXSISO30s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO30s!
# Downloading from S3 bucket!
# braindata shape: (3555, 238955)
# df shape: (3555, 8)
# Downloading betamap of sub-SAXSISO32b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO32b!
# Downloading from S3 bucket!
# braindata shape: (3609, 238955)
# df shape: (3609, 8)
# Downloading betamap of sub-SAXSISO32f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO32f!
# Downloading from S3 bucket!
# braindata shape: (3663, 238955)
# df shape: (3663, 8)
# Downloading betamap of sub-SAXSISO32s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO32s!
# Downloading from S3 bucket!
# braindata shape: (3717, 238955)
# df shape: (3717, 8)
# Downloading betamap of sub-SAXSISO33b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO33b!
# Downloading from S3 bucket!
# braindata shape: (3771, 238955)
# df shape: (3771, 8)
# Downloading betamap of sub-SAXSISO33f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO33f!
# Downloading from S3 bucket!
# braindata shape: (3825, 238955)
# df shape: (3825, 8)
# Downloading betamap of sub-SAXSISO33s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO33s!
# Downloading from S3 bucket!
# braindata shape: (3879, 238955)
# df shape: (3879, 8)
# Downloading betamap of sub-SAXSISO34b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO34b!
# Downloading from S3 bucket!
# braindata shape: (3933, 238955)
# df shape: (3933, 8)
# Downloading betamap of sub-SAXSISO34f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO34f!
# Downloading from S3 bucket!
# braindata shape: (3987, 238955)
# df shape: (3987, 8)
# Downloading betamap of sub-SAXSISO34s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO34s!
# Downloading from S3 bucket!
# braindata shape: (4041, 238955)
# df shape: (4041, 8)
# Downloading betamap of sub-SAXSISO35b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO35b!
# Downloading from S3 bucket!
# braindata shape: (4095, 238955)
# df shape: (4095, 8)
# Downloading betamap of sub-SAXSISO35f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO35f!
# Downloading from S3 bucket!
# braindata shape: (4149, 238955)
# df shape: (4149, 8)
# Downloading betamap of sub-SAXSISO35s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO35s!
# Downloading from S3 bucket!
# braindata shape: (4203, 238955)
# df shape: (4203, 8)
# Downloading betamap of sub-SAXSISO36b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO36b!
# Downloading from S3 bucket!
# braindata shape: (4257, 238955)
# df shape: (4257, 8)
# Downloading betamap of sub-SAXSISO36f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO36f!
# Downloading from S3 bucket!
# braindata shape: (4311, 238955)
# df shape: (4311, 8)
# Downloading betamap of sub-SAXSISO36s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO36s!
# Downloading from S3 bucket!
# braindata shape: (4365, 238955)
# df shape: (4365, 8)
# Downloading betamap of sub-SAXSISO38b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO38b!
# Downloading from S3 bucket!
# braindata shape: (4419, 238955)
# df shape: (4419, 8)
# Downloading betamap of sub-SAXSISO38f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO38f!
# Downloading from S3 bucket!
# braindata shape: (4473, 238955)
# df shape: (4473, 8)
# Downloading betamap of sub-SAXSISO38s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO38s!
# Downloading from S3 bucket!
# braindata shape: (4527, 238955)
# df shape: (4527, 8)
# Downloading betamap of sub-SAXSISO39b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO39b!
# Downloading from S3 bucket!
# braindata shape: (4581, 238955)
# df shape: (4581, 8)
# Downloading betamap of sub-SAXSISO39f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO39f!
# Downloading from S3 bucket!
# braindata shape: (4617, 238955)
# df shape: (4617, 8)
# Downloading betamap of sub-SAXSISO39s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO39s!
# Downloading from S3 bucket!
# braindata shape: (4671, 238955)
# df shape: (4671, 8)
# Downloading betamap of sub-SAXSISO40b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO40b!
# Downloading from S3 bucket!
# braindata shape: (4725, 238955)
# df shape: (4725, 8)
# Downloading betamap of sub-SAXSISO40f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO40f!
# Downloading from S3 bucket!
# braindata shape: (4779, 238955)
# df shape: (4779, 8)
# Downloading betamap of sub-SAXSISO40s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO40s!
# Downloading from S3 bucket!
# braindata shape: (4833, 238955)
# df shape: (4833, 8)
# Downloading betamap of sub-SAXSISO41b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO41b!
# Downloading from S3 bucket!
# braindata shape: (4887, 238955)
# df shape: (4887, 8)
# Downloading betamap of sub-SAXSISO41f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO41f!
# Downloading from S3 bucket!
# braindata shape: (4941, 238955)
# df shape: (4941, 8)
# Downloading betamap of sub-SAXSISO41s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO41s!
# Downloading from S3 bucket!
# braindata shape: (4995, 238955)
# df shape: (4995, 8)
# Downloading betamap of sub-SAXSISO42b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO42b!
# Downloading from S3 bucket!
# braindata shape: (5049, 238955)
# df shape: (5049, 8)
# Downloading betamap of sub-SAXSISO42f!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO42f!
# Downloading from S3 bucket!
# braindata shape: (5103, 238955)
# df shape: (5103, 8)
# Downloading betamap of sub-SAXSISO42s!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO42s!
# Downloading from S3 bucket!
# braindata shape: (5157, 238955)
# df shape: (5157, 8)
# Downloading betamap of sub-SAXSISO01b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO01b!
# Downloading from S3 bucket!
# braindata shape: (5317, 238955)
# df shape: (5317, 8)
# Downloading betamap of sub-SAXSISO02b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO02b!
# Downloading from S3 bucket!
# braindata shape: (5477, 238955)
# df shape: (5477, 8)
# Downloading betamap of sub-SAXSISO03b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO03b!
# Downloading from S3 bucket!
# braindata shape: (5637, 238955)
# df shape: (5637, 8)
# Downloading betamap of sub-SAXSISO04b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO04b!
# Downloading from S3 bucket!
# braindata shape: (5797, 238955)
# df shape: (5797, 8)
# Downloading betamap of sub-SAXSISO08b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO08b!
# Downloading from S3 bucket!
# braindata shape: (5957, 238955)
# df shape: (5957, 8)
# Downloading betamap of sub-SAXSISO09b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO09b!
# Downloading from S3 bucket!
# braindata shape: (6117, 238955)
# df shape: (6117, 8)
# Downloading betamap of sub-SAXSISO10b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO10b!
# Downloading from S3 bucket!
# braindata shape: (6277, 238955)
# df shape: (6277, 8)
# Downloading betamap of sub-SAXSISO11b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO11b!
# Downloading from S3 bucket!
# braindata shape: (6437, 238955)
# df shape: (6437, 8)
# Downloading betamap of sub-SAXSISO12b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO12b!
# Downloading from S3 bucket!
# braindata shape: (6597, 238955)
# df shape: (6597, 8)
# Downloading betamap of sub-SAXSISO13b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO13b!
# Downloading from S3 bucket!
# braindata shape: (6757, 238955)
# df shape: (6757, 8)
# Downloading betamap of sub-SAXSISO14b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO14b!
# Downloading from S3 bucket!
# braindata shape: (6917, 238955)
# df shape: (6917, 8)
# Downloading betamap of sub-SAXSISO15b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO15b!
# Downloading from S3 bucket!
# braindata shape: (7077, 238955)
# df shape: (7077, 8)
# Downloading betamap of sub-SAXSISO17b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO17b!
# Downloading from S3 bucket!
# braindata shape: (7237, 238955)
# df shape: (7237, 8)
# Downloading betamap of sub-SAXSISO18b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO18b!
# Downloading from S3 bucket!
# braindata shape: (7397, 238955)
# df shape: (7397, 8)
# Downloading betamap of sub-SAXSISO19b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO19b!
# Downloading from S3 bucket!
# braindata shape: (7557, 238955)
# df shape: (7557, 8)
# Downloading betamap of sub-SAXSISO21b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO21b!
# Downloading from S3 bucket!
# braindata shape: (7717, 238955)
# df shape: (7717, 8)
# Downloading betamap of sub-SAXSISO22b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO22b!
# Downloading from S3 bucket!
# braindata shape: (7877, 238955)
# df shape: (7877, 8)
# Downloading betamap of sub-SAXSISO24b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO24b!
# Downloading from S3 bucket!
# braindata shape: (8037, 238955)
# df shape: (8037, 8)
# Downloading betamap of sub-SAXSISO26b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO26b!
# Downloading from S3 bucket!
# braindata shape: (8197, 238955)
# df shape: (8197, 8)
# Downloading betamap of sub-SAXSISO27b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO27b!
# Downloading from S3 bucket!
# braindata shape: (8357, 238955)
# df shape: (8357, 8)
# Downloading betamap of sub-SAXSISO28b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO28b!
# Downloading from S3 bucket!
# braindata shape: (8517, 238955)
# df shape: (8517, 8)
# Downloading betamap of sub-SAXSISO30b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO30b!
# Downloading from S3 bucket!
# braindata shape: (8677, 238955)
# df shape: (8677, 8)
# Downloading betamap of sub-SAXSISO32b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO32b!
# Downloading from S3 bucket!
# braindata shape: (8837, 238955)
# df shape: (8837, 8)
# Downloading betamap of sub-SAXSISO33b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO33b!
# Downloading from S3 bucket!
# braindata shape: (8997, 238955)
# df shape: (8997, 8)
# Downloading betamap of sub-SAXSISO34b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO34b!
# Downloading from S3 bucket!
# braindata shape: (9157, 238955)
# df shape: (9157, 8)
# Downloading betamap of sub-SAXSISO35b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO35b!
# Downloading from S3 bucket!
# braindata shape: (9317, 238955)
# df shape: (9317, 8)
# Downloading betamap of sub-SAXSISO36b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO36b!
# Downloading from S3 bucket!
# braindata shape: (9477, 238955)
# df shape: (9477, 8)
# Downloading betamap of sub-SAXSISO38b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO38b!
# Downloading from S3 bucket!
# braindata shape: (9637, 238955)
# df shape: (9637, 8)
# Downloading betamap of sub-SAXSISO39b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO39b!
# Downloading from S3 bucket!
# braindata shape: (9797, 238955)
# df shape: (9797, 8)
# Downloading betamap of sub-SAXSISO40b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO40b!
# Downloading from S3 bucket!
# braindata shape: (9957, 238955)
# df shape: (9957, 8)
# Downloading betamap of sub-SAXSISO41b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO41b!
# Downloading from S3 bucket!
# braindata shape: (10117, 238955)
# df shape: (10117, 8)
# Downloading betamap of sub-SAXSISO42b!
# Downloading from S3 bucket!
# Converting into Brain_Data!
# Downloading eventfile of sub-SAXSISO42b!
# Downloading from S3 bucket!
# braindata shape: (10277, 238955)
# df shape: (10277, 8)
# Concatenation finished!
# Braindata.data shape: (10277, 238955)
# Braindata.Y:             session   trial_type
# 0    sub-SAXSISO01b         Food
# 1    sub-SAXSISO01b      Control
# 2    sub-SAXSISO01b       Social
# 3    sub-SAXSISO01b         Food
# 4    sub-SAXSISO01b       Social
# ..              ...          ...
# 155  sub-SAXSISO42b  ButtonPress
# 156  sub-SAXSISO42b  NonRewarded
# 157  sub-SAXSISO42b  ButtonPress
# 158  sub-SAXSISO42b  NonRewarded
# 159  sub-SAXSISO42b  ButtonPress
#
# [10277 rows x 2 columns]
# Saving your cocatenation outputs!
# Uplaoding to S3 bucket!
# 3995 seconds
# 67 minutes
